# %% [markdown]
# <a href="https://colab.research.google.com/github/Junioroque/Aprendendo-Python/blob/main/Estudo_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cor = 'verde'
print(cor)
# Out:
# verde

# %%
print("Ola mundo!")
# Out:
# Ola mundo!

# %%
print(10 * 4)
# Out:
# 40

# %%
i = 5
type(i)
# Out:
# int

# %%
f = 9.8
type(f)
# Out:
# float

# %%
s = 'Junio'
type(s)
# Out:
# str

# %%
b = True
type(b)
# Out:
# bool

# %% [markdown]
# > Precisamos criar variáveis que armazenem os dados da ficha desse aluno. São eles:
#
# * Nome: Fabricio Daniel
# * Idade: 15 anos
# * Media do semestre: 8,45
# * Situaçao de aprovação: Verdadeira (aprovado)
#
# > Na célula abaixo, conseguimos criar esses valores.

# %%
nome = "Fabricio Daniel"
idade = 15
media = 8.45
aprovado = True
print(f'Nome {nome} idade {idade} obteve a media {media} aprovado = {aprovado}')
# Out:
# Nome Fabricio Daniel idade 15 obteve a media 8.45 aprovado = True

# %% [markdown]
# Cinco pessoas trabalham como seguranças e recebem um salário de 3 mil reais.
#
# Dezesseis pessoas trabalham como docentes e recebem um salário de 6 mil reais.
#
# Por fim, temos uma pessoa que trabalha na diretoria e seu salário é de 12 mil e 500 reais.
#
# Precisamos trabalhar com esses dados fornecendo:
#
# * A quantidade total de empregados;
# * A diferença entre o salário mais baixo e mais alto;
# * A média ponderada da faixa salarial da escola.

# %%
q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

# %%
total_empregado = q_seguranca + q_docente + q_diretoria
total_empregado
# Out:
# 22

# %%
diferenca_salario = s_diretoria - s_seguranca
diferenca_salario
# Out:
# 9500

# %%
media = (q_seguranca*s_seguranca + q_docente*s_docente + q_diretoria*s_diretoria)/(total_empregado)
media
# Out:
# 5613.636363636364

# %%
#Criar string
s1 = 'Alura'
s2 = "Curso"
print(s1, s2)
print(type(s1), type(s2))
# Out:
# Alura Curso
# <class 'str'> <class 'str'>

# %%
# manipular String
texto = 'Geovana Alessandra'
print(texto[0])
print(texto[1])
print(texto[2])
# Out:
# G
# e
# o

# %%
texto.upper()
# Out:
# 'GEOVANA ALESSANDRA'

# %%
texto.lower()
# Out:
# 'geovana alessandra'

# %%
texto.strip()
# Out:
# 'Geovana Alessandra'

# %%
texto.replace('a', '@')
# Out:
# 'Geov@n@ Aless@ndr@'

# %%
texto = texto.replace('a', '@')
print(texto)
# Out:
# Geov@n@ Aless@ndr@

# %%
# Coletar dados input
nome = input('Digite seu nome: ')
print(f'Olá, {nome}!')
# Out:
# Digite seu nome: Junio
# Olá, Junio!

# %%
numero = int(input('Digite um numero: '))
print(f'O numero informado foi {numero}')
print(type(numero))
# Out:
# Digite um numero: 66
# O numero informado foi 66
# <class 'int'>

# %%
salario = float(input('Digite o valor do salario: '))
print(f'O salario que você recebe: {salario}')
# Out:
# Digite o valor do salario: 1200.53
# O salario que você recebe: 1200.53

# %%
nome_aluno = 'Fabricio Daniel'
print('Nome do aluno: %s'%nome_aluno)
# Out:
# Nome do aluno: Fabricio Daniel

# %%
x = True
print("Valor de x: %s" % str(x))
# Out:
# Valor de x: True

# %% [markdown]
# # Coleta e amostragem de dados

# %% [markdown]
# Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.

# %%
nome = input("Digite seu nome: ")
print(f'Olá, {nome}!')
# Out:
# Digite seu nome: Junio
# Olá, Junio!

# %% [markdown]
# Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
print(f'Olá, {nome} você tem {idade} anos.')
# Out:
# Digite seu nome: Junio
# Digite sua idade: 42
# Olá, Junio você tem 42 anos.

# %% [markdown]
# Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
print(f'Olá, {nome} a sua altura é {altura}, você tem {idade} anos.')
# Out:
# Digite seu nome: Junio
# Digite sua idade: 42
# Digite sua altura: 1.79
# Olá, Junio a sua altura é 1.79, você tem 42 anos.

# %% [markdown]
# # Calculadora com operadores

# %% [markdown]
# Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma dos dois valores.

# %%
numero1 = int(input("Digite o primeiro numero: "))
numero2 = int(input("Digite o segundo numero: "))
soma = numero1 + numero2
print(f'A soma dos dois numeros é {soma}')
# Out:
# Digite o primeiro numero: 2
# Digite o segundo numero: 3
# A soma dos dois numeros é 5

# %% [markdown]
# Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.

# %%
numero1 = int(input("Digite o primeiro numero: "))
numero2 = int(input("Digite o segundo numero: "))
numero3 = int(input("Digite o terceiro numero: "))
soma = numero1 + numero2 + numero3
print(f'A soma dos três numeros é {soma}')
# Out:
# Digite o primeiro numero: 1
# Digite o segundo numero: 3
# Digite o terceiro numero: 4
# A soma dos três numeros é 8

# %% [markdown]
# Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.

# %%
numero1 = int(input("Digite o primeiro numero: "))
numero2 = int(input("Digite o segundo numero: "))
multiplicacao = numero1 * numero2
print(f'A multiplicação dos dois numeros é {multiplicacao}')

# %% [markdown]
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
numerador = int(input("Digite o numerador: "))
denominador = int(input("Digite o denominador: "))
if denominador == 0:
    print("O denominador não pode ser 0")
else:
    divisao = numerador / denominador
    print(f'A divisão dos dois numeros é {divisao}')

# %% [markdown]
# Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.

# %%
valor1 = float(input("Digite o primeiro valor: "))
valor2 = float(input("Digite o segundo valor: "))
potencia = valor1 ** valor2
print(f'A exponenciação entre dois valores: {potencia}')

# %% [markdown]
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
numerador = int(input("Digite o numerador: "))
denominador = int(input("Digite o denominador: "))
if denominador == 0:
    print("O denominador não pode ser 0")
else:
    divisao = numerador // denominador
    print(f'A divisão inteira do é {divisao}')

# %% [markdown]
# Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
numerador = int(input("Digite o numerador: "))
denominador = int(input("Digite o denominador: "))
if denominador == 0:
    print("O denominador não pode ser 0")
else:
    resto = numerador % denominador
    print(f'O resto da divisão é {resto}')

# %% [markdown]
# Crie um código que solicita 3 notas de um estudante e imprima a média das notas.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
media = (nota1 + nota2 + nota3)/3
print(f'A média das notas é {media}')

# %% [markdown]
# Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4.

# %%
numeros = [5, 12, 20, 15]
pesos = [1, 2, 3, 4]
media_ponderada = sum(numero * peso for numero, peso in zip(numeros, pesos)) / sum(pesos)
print(f'A média ponderada é {media_ponderada}')
# Out:
# A média ponderada é 14.9

# %% [markdown]
# # Editando textos

# %% [markdown]
# Crie uma variável chamada “frase” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase na tela.

# %%
nome = input("Digite um nome: ")
print(f'Olá, {nome}!')
# Out:
# Digite um nome: Cavalo
# Olá, Cavalo!

# %% [markdown]
# Crie um código que solicite uma frase e depois imprima a frase na tela.

# %%
texto = input("Digite uma frase: ")
print(f'A frase é {texto}')
# Out:
# Digite uma frase: O dia está lindo!
# A frase é O dia está lindo!

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras maiúsculas.

# %%
texto = input("Digite uma frase: ")
print(f'A frase é {texto.upper()}')
# Out:
# Digite uma frase: Meu nome é Junio Cezar
# A frase é MEU NOME É JUNIO CEZAR

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras minúsculas.

# %%
texto = input("Digite uma frase: ")
print(f'A frase é {texto.lower()}')
# Out:
# Digite uma frase: OI LINDAO SOU EU
# A frase é oi lindao sou eu

# %% [markdown]
# Crie uma variável chamada “frase” e atribua a ela uma string de sua escolha. Em seguida, imprima a frase sem espaços em branco no início e no fim.

# %%
frase = ' Jóia, e ouro ou diamente '
print(frase.strip())
print(frase)
# Out:
# Jóia, e ouro ou diamente
#  Jóia, e ouro ou diamente

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim.

# %%
frase = input("Digite uma frase: ")
print(frase.strip())
# Out:
# Digite uma frase: Ola meu nome e Junio
# Ola meu nome e Junio

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim e em letras minúsculas.

# %%
frase = input("Digite uma frase: ")
print(frase.strip().lower())
# Out:
# Digite uma frase: Olá meu nome e Junio o BICHAO
# olá meu nome e junio o bichao

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “e” trocadas pela letra “f”.

# %%
frase = input("Digite uma frase: ")
for x in "aeiouAEIOU":
    frase = frase.replace(x, "f")

print(frase)
# Out:
# Digite uma frase: Oi meu nome e Junio Cezar
# ff mff nfmf f Jfnff Cfzfr

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “a” trocadas pela caractere “@”.

# %%
frase = input("Digite uma frase: ")
for x in "aA":
    frase = frase.replace(x, "@")

print(frase)
# Out:
# Digite uma frase: Hoje é um dia muito lindo  e parece que vai chuver.
# Hoje é um di@ muito lindo  e p@rece que v@i chuver.

# %% [markdown]
# Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as consoantes “s” trocadas pelo caractere “$”.

# %%
frase = input("Digite uma frase: ")
for x in "sS":
    frase = frase.replace(x, "$")

print(frase)
# Out:
# Digite uma frase: Amanha vai jogar a seleção brasileira São Paulo Futebol Clube.
# Amanha vai jogar a $eleção bra$ileira $ão Paulo Futebol Clube.

# %% [markdown]
# # Estrutura Condicionais

# %%
# A avaliar uma condição
if 2 < 7:
  print("2 é menor que 7")
# Out:
# 2 é menor que 7

# %%
if 8 < 7:
  print("Verdade")
else:
  print("Falso")
# Out:
# Falso

# %%
lista = 'Alice, Bernardo, Cecília, Davi, Eloá, Francisco, Gael, Helena, Ícaro, Júlia, Kaique, Liz, Maitê, Noah, Olívia, Pedro, Ravi, Sophia, Théo, Valentina, Arthur, Beatriz, Cauã, Diana, Enzo, Flora, Gabriel, Heitor, Isis, Joaquim, Kauê, Lavínia, Miguel, Nina, Otávio, Pietra, Queren, Ruan, Stella, Tomás, Uriel, Vitória, Wesley, Xande, Yasmin, Zeca, Aurora, Benjamin, Cora, Dante'

# %%
nome_1 = 'Gael'
nome_2 = 'Carla'
if nome_1 in lista:
  print(f'{nome_1} está na lista')
else:
  print(f'{nome_1} não está na lista')
# Out:
# Gael está na lista

# %% [markdown]
# # Aquecendo na programação praticar Estrutura condicionais

# %% [markdown]
# Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
numero_1 = int(input("Digite o primeiro numero: "))
numero_2 = int(input("Digite o segundo numero: "))
if numero_1 > numero_2:
  print(f'O numero maior é {numero_1}')
else:
  print(f'O numero maior é {numero_2}')
# Out:
# Digite o primeiro numero: 11
# Digite o segundo numero: 5
# O numero maior é 11

# %% [markdown]
# Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
percentual = int(input("Digite o percentual de crescimento: "))
if percentual > 0:
  print(f'Houve um crescimento de porcentagem positiva')
elif pecentual < 0:
  print(f'Houve um decrescimento de porcentagem negativa')
else:
  print(f'Não houve crescimento nem decrescimento')
# Out:
# Digite o percentual de crescimento: 2
# Houve um crescimento de porcentagem positiva

# %% [markdown]
# Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
vogal = 'aeiouAEIOU'
letra = input("Digite uma letra: ")
if(letra in vogal):
  print(f'{letra} é uma vogal')
else:
  print(f'{letra} é uma consoante')
# Out:
# Digite uma letra: e
# e é uma vogal

# %% [markdown]
# Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
print('Digite 3 valores de um modelo de carro dos 3 anos consecutivo?')
valor1 = float(input("Digite o primeiro valor: "))
valor2 = float(input("Digite o segundo valor: "))
valor3 = float(input("Digite o terceiro valor: "))

# Criar uma lista com os valores para encontrar o máximo e o mínimo
valores = [valor1, valor2, valor3]

maior = max(valores)
menor = min(valores)

print(f'Maior valor: {maior}')
print(f'Menor valor: {menor}')
# Out:
# Digite 3 valores de um modelo de carro dos 3 anos consecutivo?
# Digite o primeiro valor: 5
# Digite o segundo valor: 6
# Digite o terceiro valor: 2
# Maior valor: 6.0
# Menor valor: 2.0

# %% [markdown]
# Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
print('Insira três preços de produtos pesquisado?')
preco_1 = float(input('Digite o preço do produto: '))
preco_2 = float(input('Digite o preço do produto: '))
preco_3 = float(input('Digite o preço do produto: '))
lista = [preco_1, preco_2, preco_3]
menor = min(lista)
print(f'O produto mais barato custa {menor}')
# Out:
# Insira três preços de produtos pesquisado?
# Digite o preço do produto: 6.22
# Digite o preço do produto: 5.25
# Digite o preço do produto: 9.00
# O produto mais barato custa 5.25

# %% [markdown]
#  Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
mensagem = '''
Qual desse turno você quer estudar:
1- Manhã
2- Tarde
3- Noite
'''
print(mensagem)
numero = int(input("Digite o numero desejado: "))
match numero:
    case 1:
        print("Bom dia!")
    case 2:
        print("Boa tarde!")
    case 3:
        print("Boa noite!")
    case _:
        print("Valor inválido!")
# Out:
# Qual desse turno você quer estudar:
# 1- Manhã
# 2- Tarde
# 3- Noite
#
# Digite o numero desejado: 1
# Bom dia!

# %% [markdown]
# Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
numero = int(input('Digite um numero inteiro: '))
if numero % 2 == 0:
  print(f'{numero} é par')
else:
  print(f'{numero} é impar')
# Out:
# Digite um numero inteiro: 11
# 11 é impar

# %% [markdown]
# # Momento dos projetos

# %% [markdown]
# Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# * Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# * Triângulo Equilátero: três lados iguais;
# * Triângulo Isósceles: quaisquer dois lados iguais;
# * Triângulo Escaleno: três lados diferentes.

# %% [markdown]
# Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
# * O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
# * O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %% [markdown]
# Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
# * Para variação acima de 20%: bonificação para o time de vendas.
# * Para variação entre 2% e 20%: pequena bonificação para time de vendas.
# * Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
# * Para variação abaixo de -10%: corte de gastos.
